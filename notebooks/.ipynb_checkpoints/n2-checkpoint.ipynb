# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
traffic = pd.read_csv(r"C:\Users\HP\Downloads\week00_data\traffic.csv")

# %%
traffic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 12 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   GlobalRank      1000000 non-null  int64
#  1   TldRank         1000000 non-null  int64
#  2   Domain          1000000 non-null  object
#  3   TLD             1000000 non-null  object
#  4   RefSubNets      1000000 non-null  int64
#  5   RefIPs          1000000 non-null  int64
#  6   IDN_Domain      1000000 non-null  object
#  7   IDN_TLD         1000000 non-null  object
#  8   PrevGlobalRank  1000000 non-null  int64
#  9   PrevTldRank     1000000 non-null  int64
#  10  PrevRefSubNets  1000000 non-null  int64
#  11  PrevRefIPs      1000000 non-null  int64
# dtypes: int64(8), object(4)
# memory usage: 91.6+ MB

# %%
traffic.isnull().sum()
# Out:
# GlobalRank        0
# TldRank           0
# Domain            0
# TLD               0
# RefSubNets        0
# RefIPs            0
# IDN_Domain        0
# IDN_TLD           0
# PrevGlobalRank    0
# PrevTldRank       0
# PrevRefSubNets    0
# PrevRefIPs        0
# dtype: int64

# %%
traffic.shape
# Out:
# (1000000, 12)

# %% [markdown]
#  top and bottom 10 Websites with the highest numbers of visitors traffic

# %% [markdown]
# Assuming Higher Referring Subnets/IPs Indicate Higher Traffic

# %%
# Sort by RefSubNets 
top_traffic_domains = traffic.sort_values(by='RefSubNets', ascending=False).head(10)  # Top 10 domains
bottom_traffic_domains = traffic.sort_values(by='RefSubNets', ascending=False).tail(10)  # Bottom 10 domains (by highest RefSubNets)

# %%
top_traffic_domains
# Out:
#    GlobalRank  TldRank                Domain  TLD  RefSubNets   RefIPs  \
# 0           1        1            google.com  com      471274  2151358
# 1           2        2          facebook.com  com      465424  2250631
# 2           3        3           youtube.com  com      420579  1852995
# 3           4        4           twitter.com  com      404985  1757127
# 4           5        5         instagram.com  com      364746  1598085
# 5           6        6          linkedin.com  com      337391  1319082
# 6           7        7             apple.com  com      263655   804726
# 7           8        8         microsoft.com  com      260546   739096
# 8           9        9  googletagmanager.com  com      254115   863843
# 9          10        1         wikipedia.org  org      246612   831384
#
#              IDN_Domain IDN_TLD  PrevGlobalRank  PrevTldRank  PrevRefSubNets  \
# 0            google.com     com               1            1          471248
# ...

# %%
bottom_traffic_domains
# Out:
#         GlobalRank  TldRank                           Domain  TLD  RefSubNets  \
# 999257      999258   484938                   beninlotto.com  com         222
# 999258      999259   484939                     jgpe-tea.com  com         222
# 999259      999260    30507    schluesseldienst-24-bochum.de   de         222
# 999260      999261    30508  schluesseldienst-swisttal-24.de   de         222
# 999261      999262   484940                   allpettoys.com  com         222
# 999262      999263   484941                  danielderek.com  com         222
# 999263      999264   484942                    fiboomgas.com  com         222
# 999264      999265   484943                    safe-navi.com  com         222
# 999265      999266    30509    schluesseldienst-fuerth-24.de   de         222
# 999999     1000000   485328           toyotamusicfactory.com  com         222
#
#         RefIPs                       IDN_Domain IDN_TLD  PrevGlobalRank  \
# ...
